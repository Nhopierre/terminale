# %% [markdown]
# # Calcul du taux d'avancement final pour une solution d'un acide faible.

# %% [markdown]
# <div class = 'alert alert-info'>
# Pour exécuter le code écrit dans un bloc : <b>MAJ-ENTREE </b><br>
#     Pour recommencer depuis le début : Menu <b>Kernel / Restart and clear output </b><br>
#     Toujours exécuter dans l'ordre le code  écrit dans les blocs précédés de la mention <b>Entrée  [  ]</b>
# </div>

# %% [markdown]
# <div class = 'alert alert-warning'>Importation de module de calcul.
#     </div>

# %%
import math

# %% [markdown]
# ## 1. Données.

# %% [markdown]
# <div class = 'alert alert-warning'>
#     On note <b>Capp</b> la concentration apportée de l'acide faible AH. Sa base conjuguée est noté A<sup>-</sup>. <br>
#     Les valeurs sont données en mol.L<sup>-1</sup>
#     <hr>
# Données à compléter pour une solution de l'acide faible indiqué dans le sujet avec la concentration apportée donnée.
#     </div>

# %%
pKa = 
Capp =

# %% [markdown]
# ## 2. Calcul de la concentration des ions oxonium.

# %% [markdown]
# <div class = 'alert alert-warning'>
#     a) Ecrire l'équation de la réaction entre un acide faible et l'eau. <br>
#     b) Rappeler l'expression du Ka. <br>
#     c) Exprimer le Ka en fonction de [H<sub>3</sub>O<sup>+</sup>] que l'on notera <b>h</b> et de <b>Capp</b>.<br>
#     d) En déduire une équation du second degré que l'on écrira sous la forme :<br>
#     $$
#     h^2 + b\times h + c = 0
#     $$
#     e) Quelles sont les expressions de <b>b</b> et <b>c</b> dans l'équation précédente ?<br>
# <hr>
#     La fonction <code class = "python">calcul_h</code> calcule la <b>concentration des ions oxoniums dans l'état final</b> à partir des valeurs du pKa et de la concentration apportée de l'acide. <br>
#     Compléter les lignes permettant de calculer <code class = "python">Ka</code>, <code class = "python">b</code>, <code class = "python">c</code>,le déterminant <code class = "python">delta</code> et la concentration final de [H<sub>3</sub>O<sup>+</sup>] notée <code class = "python">h</code>.
#     </div>

# %%
def calcul_h(Capp,pKa):
    Ka = 
    b =  
    c = 
    delta = 
    racine_delta = math.sqrt(delta)
    h = 
    return h

# %% [markdown]
# ## 3. Utilisation du modèle.

# %% [markdown]
# <div class = 'alert alert-warning'>
#     Compléter dans la fonction <code class = "python">resultats</code>, les lignes permettant de calculer à partir de la concentration des ions oxonium <code class = "python">h</code> et de la concentration apportée <code class = "python">Capp</code> : <br>
#     - le taux d'avancement final <code class = "python">tau</code>, <br>
#     - la concentration de l'acide <code class = "python">C_AH</code>, <br>
#     - celle de la base conjuguée <code class = "python">C_A</code> et <br>
#     - le <code class = "python">pH</code> (le logarithme décimal est calculé par la fonction <code class = "python">math.log10(...)</code>
#     </div>

# %%
def resultats ( h, Capp):
    tau = 
    C_A = 
    C_AH = 
    pH = 
    print("Concentration de l'acide", "%.2e"% C_AH, "mol/L")
    print("Concentration de la base", "%.2e"% C_A, "mol/L")
    print("pH de la solution",  "%.2f"% pH)
    print("le taux d'avancement final :","%.1f"% (tau*100),"%")

# %% [markdown]
# <div class = 'alert alert-warning'>
#     Appel de la fonction <code class = "python">calcul_h( , )</code> avec passage des arguments <code class = "python">pKa</code> et <code class = "python">Capp</code> pour calculer la variable <code class = "python">h</code> <hr>
#     Appel de la fonction <code class = "python">resultats( , )</code> avec passage des arguments <code class = "python">h</code> et <code class = "python">Capp</code> pour afficher les résultats</div>

# %%
h = calcul_h(Capp,pKa)
resultats (h, Capp)

# %% [markdown]
# ## 3. Limites du modèle.

# %% [markdown]
# <div class = 'alert alert-warning'>On considère un acide faible de pKa = 3,65 et de concentration apportée inférieure à 0,10 mol/L
# <hr>
# a) A partir de quelle valeur de concentration se comporte-t-il comme un acide quasi-fort? <br>
# b) A partir de quelle valeur de concentration apportée, le modèle prévoit-il des valeurs de pH incohérentes pour une solution acide ? <br>
# c) Quelle est l'hypothèse qui a été faite lors des calculs qui n'est plus valable ?<br>
# <br>
#         </div>

# %%
pKa = 
Capp = 
h = calcul_h(Capp,pKa)
resultats (h, Capp)

# %% [markdown]
# ## C'est fini
# Il ne reste plus qu'à télécharger le fichier !

# %% [markdown]
# <div class = 'alert alert-success'><h4>La commande suivante imprime toutes les lignes de code exécutées depuis la dernière initialisation de la page (Restart and Clear Output) <br><br>Cela permet de les copier dans Spyder ou dans un fichier .text par exemple.</h4></div>

# %%
# %history
